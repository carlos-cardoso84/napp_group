# %% [markdown]
# ## Pacotes

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
import pandas_profiling
import plotly.graph_objects as go
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import random

# %% [markdown]
# # AMOSTRAGEM

# %% [markdown]
# * População e amostra
#
# * Amostragem Aleatória
#
# * Amostragem Estratificada
#
# * Amostragem Aleatória Simples
#
# * Viés de Amostragem
#
# * Bootstrap

# %% [markdown]
# ## 1. População e amostra

# %% [markdown]
# **População**: Todo o conjunto de dados;
#
# **Amostra**: Um subconjunto da população;

# %%
#exemplo

# %% [markdown]
# ### 1.1 Algumas funcionalidades

# %% [markdown]
# Qual o problema da minha amostra?

# %%
#exemplo sem ordem

# %% [markdown]
# ## 2. Amostragem Aleatória

# %% [markdown]
# Extração aletória dos elementos de uma população. Considerando que todos os elementos tem igual probabilidade de serem sorteados, a amostra resultante é chamada de **amostra aleatória simples**.

# %% [markdown]
# ## 3.  Amostragem Estratificada

# %% [markdown]
# Dividir a população em estratos e selecionar amostras aleatórias em cada estrato

# %% [markdown]
# ## 4. Viés de Amostragem

# %% [markdown]
# Viés estatístico refere-se a erros de medição ou amostragem que podem ser produzidos durante o processo.

# %% [markdown]
# ![vies.png](attachment:vies.png)

# %% [markdown]
# ## 5.  Bootstrap

# %% [markdown]
# Jeito rápido e eficaz de estimar a distribuição amostral extraindo amostras adicionais, com repetição, da própria amostra.
#
# Termos chave:
#
# * Amostra Bootstrap;
#
# * Reamostragem.

# %% [markdown]
# ![bootstrap.png](attachment:bootstrap.png)

# %%
#exemplo

# %% [markdown]
# # Regressão e Previsão

# %% [markdown]
# leitura: https://www.oguiafinanceiro.com.br/textos/big-data-como-a-target-descobriu-uma-gravidez-antes-da-propria-familia/#:~:text=Na%20realidade%2C%20para%20ser%20mais,se%20encontrava%20(em%20semanas).

# %% [markdown]
# ## Vamos modelar!

# %%
# gatos e espirros

# %%
#plot

# %% [markdown]
# dados:
#
# https://www.kaggle.com/mustafaali96/weight-height/download

# %%
#carregar os dados

# %% [markdown]
# ## Lembre-se das boas práticas...

# %% [markdown]
# Objetivo: Encontrar o melhor valor de A e B pra uma equação que relacione o peso e a altura:
#
# <p>&nbsp;</p>
#
# $ \Large y(x) = A + B \cdot x $
#
# <p>&nbsp;</p>
#
# $ \Large P(h) = A + B \cdot h $
#
# Onde:
# * h = Altura
# * P(h) = Peso calculado para uma altura conhecida
# * A e B - Parâmetros da equação linear (kg)

# %% [markdown]
# ## Função Custo
#
# A função custo é definida por:
#
# $$ \Large J = \frac{1}{n} \cdot \sum_{i=1}^{n}(pred_i - y_i)^2 $$
#
# Lembrando que:
#
# * $ \Large  y_i $ é o i-ésimo resultado (dado) do nosso dataset - no nosso caso: peso.
#
# * $ \Large pred_i $ é o resultado predito para o i-éismo dado - no nosso caso o resultado da altura

# %%
# pré-processamento

# %%
#função custo

# %%
#plot

# %%
#plot com controles

# %% [markdown]
# ## Como otimizar essa busca?
#
# ### Mínimos Quadrados:
#
#
# Supondo: $$ \Large y(x) = A + B \cdot x $$
#
# <p>&nbsp;</p>
#
# Temos: $$ \Large B = \frac{n \sum x_i y_i - \sum x_i \cdot \sum y_i}{n \sum x_i^2 - (\sum x_i)^2} $$
#
# <p>&nbsp;</p>
#
# $$ \Large A = \frac{\sum y_i - B \sum x_i}{n} $$

# %%
#formula na mão

# %% [markdown]
# ## Modelando com o sklearn

# %%
#variaveis

# %% [markdown]
# ## O modelo é bom?

# %% [markdown]
# ## E para prever novos casos?

# %% [markdown]
# ## Atividade
# Passo a passo para a construção de dois modelos separados por gênero

# %% [markdown]
# ### Passo 1: separe os dados de peso e altura em dois grupos
#
# *male* = todos os registros do gênero 'Male';
#
# *female* = todos os registros do gênero 'Female';

# %% [markdown]
# ## Passo 2: Criação do modelo **male**
#
# Crie as variáveis **X_male** (altura do df male) e **y_male** (peso do df male). Obs: lembre-se do ***reshape*** para x_male

# %% [markdown]
# ## Passo 3: Regressão Linear
# Use o sklearn para construir o modelo male_lr (modelo de regressão linear tendo como variável explicativa **X_male** e variável dependente **y_male**)

# %% [markdown]
# ## Passo 4:
#
# Use o *predict* para mostrar os valores calculados pelo modelo, usando com entrada X_male. Salve o resultado na variável **pred_male**

# %% [markdown]
# ## Passo 5:
#
# Calcule as métricas **mse** e **r2** usando **y_male** e **pred_male** como entradas

# %% [markdown]
# ## Passo 6:
# Plot o resultado

# %% [markdown]
# ## Repita os passos de 1 a 6 e crie o modelo female_lr
